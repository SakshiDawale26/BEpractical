# %%
# if string
name='sakshi'
age = 21
#print(f"Hello, My name is {name} and I'm {age} years old.")
message=f"hello, my is {name} and i am {age} year old."
print(message)
# Out:
# hello, my is sakshi and i am 21 year old.

# %%
# Variable acces
user= {"name":"sakshi","email":"sakshi@gmail.com"}
greating= f"hello {user ['name']} your EmailId {user['email']}"
print (greating)
# Out:
# hello sakshi your EmailId sakshi@gmail.com

# %%
# f string with multiple string
name="sakshi"
age=21
bio=f"""
Name = {name}
Age = {age}
bio={name}is {age}year old and love to live her life by her own way.
"""
print (bio)
# Out:
# Name = sakshi
# Age = 21
# bio=sakshiis 21year old and love to live her life by her own way.

# %%
integer= input("Enter the integer")
if integer/2==0;
 print("it is even integer")
else:
 print("it is odd integer")
# Out:
#   Cell In[15], line 2
#     if integer/2==0;
#                    ^
# SyntaxError: invalid syntax
