# %%
# leap year checker
year=int(input("Enter a year:") )
if(year%4 ==0 and year%100!=0)or(year%400==0):
    print(f"{year}is a leap year.")
else:
    print(f"{year}is not leap year")
# Out:
# Enter a year: 2003
# 2003is not leap year

# %%
#prime number
number=int(input("Enter a number:"))

if(number%1==0 and number%number==0):
   print(f"{number}is prime number.")
else:
   print(f"{number}is not prime number")
# Out:
# Enter a number: 7
# 7is prime number.

# %%
def is_prime(number):
 if number <=1:
     return False
     return True
number = int(input("Enter a number to check if it is prime:"))
if is_prime(number):
    print(f"The number {number} is prime number.")
else:
    print(f"the number {number} is not prime number.")
# Out:
# Enter a number to check if it is prime: 2003
# the number 2003 is not prime number.

# %%
# string methods
# concatnation
str1 ="hello"
str2 ="world"
result = str1+ " " +str2
print (result)
# Out:
# hello world

# %%
# Repeatation
str1= "sakshi"
result= str1*5
print (result)
# Out:
# sakshisakshisakshisakshisakshi

# %%
#slicing and indexing
text ="python"
first_char= text[0]
last_char=text[-1]
slice_text = text [1:4]
print( first_char,last_char,slice_text)
# Out:
# p n yth

# %%
# Length
text = "RamnathReaddy D Y Patil college of Engineering"
length = len (text)
print(length)
# Out:
# 46

# %%
#Membership
text = "hello,world!"
exists = "hello" in text
print(exists)
# Out:
# True

# %%
#srting upper
text = "d y patil college of engineering"
print(text.upper())
# Out:
# D Y PATIL COLLEGE OF ENGINEERING

# %%
#srting lower
text = "D Y PATIL COLLEGE OF ENGINEERING"
print(text.lower())
# Out:
# d y patil college of engineering

# %%
#srting capitalise
text = "d y patil college of engineering"
print(text.capitalize())
# Out:
# D y patil college of engineering

# %%
#sring swap
text = " Hellow world"
print(text.swapcase())
# Out:
#  hELLOW WORLD

# %%
#slit the string
text = "hello,world!"
print (text.split())
print (text.split(','))
# Out:
# ['hello,world!']
# ['hello', 'world!']
