# %%
print("hello")
# Out:
# hello

# %%
# Arithmatic Operators

# %%
# Addition operator
a=10
b=20
c=a+b
print (c)
# Out:
# 30

# %%
# substraction operator
a=10
b=5
c=a-b
print (c)
# Out:
# 5

# %%
a=10
b=20
c=a*b
d=a/b
e=a%b  #modulo
f=a//b #floor
g=a**b #exponntial
print (c)
print (d)
print (e)
print (f)
print (g)
# Out:
# 200
# 0.5
# 10
# 0
# 100000000000000000000

# %%
# Comparision Operator
a=10
b=5
c=a==b
print (c)
# Out:
# False

# %%
a=10
b=5
c=a!=b
print (c)
# Out:
# True

# %%
a=10
b=5
c=a<b
print (c)
# Out:
# False

# %%
a=10
b=5
c=a>b
print (c)
# Out:
# True

# %%
a=10
b=5
c=a<=b
print (c)
# Out:
# False

# %%
a=10
b=5
c=a>=b
print (c)
# Out:
# True

# %%
#Logical Operator
a=2
b=1
print (a and b)
print (a and a)
print (b and b)
print (b and a)
# Out:
# 1
# 2
# 1
# 2

# %%
# pass atatement
a=10
b=20
if a>b :
   pass
print("a is not greater than b")
# Out:
# a is not greater than b

# %%
##########split string rigt to specific separator
text = "one, two, three, four"
print(text.rsplit(' ',1))
# Out:
# ['one, two, three,', 'four']

# %%
#split the string at line breaks.
# split the string at line break
text = "Hellow\nWorld\n!"
print(text)
print(text.splitlines())
# Out:
# Hellow
# World
# !
# ['Hellow', 'World', '!']

# %%
#join the element of an iteration
words= ["hello","python","world"]
print (" ".join(words))
# Out:
# hello python world

# %%
#return the lowest index where lowest substring is found
text ="hello, world, python!"
print(text.find("world"))
# Out:
# 7

# %%
#return the lowest index where lowest substring is found
#hello,world,sakshi 
#123456789101112-sakshi
text ="hello,world,sakshi ,vaishnavi!"
print(text.find("sakshi"))
# Out:
# 12

# %%
# like find(), but raises a valueError if the substring is not found
text ="hello,python,world!"
print(text.index("world"))
# Out:
# 13

# %%
#replaces occurrences of a substring with a new string.
text ="hello,world!"
print(text.replace("world","python"))
# Out:
# hello,python!

# %%
text ="python,python,python"
print(text.replace("python","pythons"))
# Out:
# pythons,pythons,pythons

# %% [markdown]
# Trimming

# %%
 # remove leadind and trailing characters.
text ="        hello,world!          "
print(text)
print(text.strip()) # space strip
# Out:
#         hello,world!
# hello,world!

# %%
#remove leadind characters.
# first space remove only
text ="        hello,world!          "
print(text)
print(text.lstrip())
# Out:
#         hello,world!
# hello,world!

# %%
##remove leadind characters.
text ="         hello,world!          "
print(text)
print(text.rstrip())
# Out:
#          hello,world!
#          hello,world!

# %% [markdown]
#  Sring testing

# %%
# check if the srting starts with the specifified prifix.
text = "hello,world!"
print(text.startswith("hello"))
# Out:
# True

# %%
# check if all characters are alphabetic.
text = "A2345ello"# is alphabetic
print(text.isalpha())
# Out:
# False

# %%
text = "A2345ello"# is alphabetic
print(text.isalnum())
# Out:
# True

# %%
# check if  the string contains only whitespaces.

# %%
# list of string 
string = ["banana","papaya","guava","pineapple"]
print (string)
# Out:
# ['banana', 'papaya', 'guava', 'pineapple']

# %%
# list of integers
numbers = [1,2,3,4,5]
print (numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#mixed data type
mixed_list = [1,"hello",3.15,True,'s']
print(mixed_list)
# Out:
# [1, 'hello', 3.15, True, 's']

# %%
# using the list( function)
another_list = list ((1,2,3,4,5))
print(another_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Accessing Elements in list

# %%
# accessing element
fruits=["apple","banana","cherry","pineapple"]
print(fruits[0])
print(fruits[1])
print(fruits[-1])
# Out:
# apple
# banana
# pineapple

# %%
# slicing list 
print(fruits[1:3])
print(fruits[:2])
print(fruits[1:])
# Out:
# ['banana', 'cherry']
# ['apple', 'banana']
# ['banana', 'cherry', 'pineapple']

# %% [markdown]
# Modifying list

# %%
# adding element
# list of fruits
fruits=["apple","banana"]

# append an item to the end
fruits.append("cherry")
print(fruits)

# extend the list with another
fruits.extend(["date","elderberry"])
print(fruits)

# insert an item at a specific position
fruits.insert(1,"blueberry")
print (fruits)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'date', 'elderberry']
# ['apple', 'blueberry', 'banana', 'cherry', 'date', 'elderberry']

# %%
# list of fruits
fruits= ["apple", "banana", "cherry","banana"]
# remove occurrence of an item
fruits.remove("banana")
print(fruits)
# remove item at specific position and return it
popped_item = fruits.pop(1)
print(popped_item)
print(fruits)
# remove the last item and returm it
last_item = fruits.pop
print(last_item)
print(fruits)
# clear the entire list
fruits.clear()
print(fruits)
# Out:
# ['apple', 'cherry', 'banana']
# cherry
# ['apple', 'banana']
# <built-in method pop of list object at 0x000001FA6CB0D880>
# ['apple', 'banana']
# []

# %% [markdown]
# Changing Elements

# %%
# list of fruits
fruits =["apple","banana","cherry"]
print(fruits)
# change an element by index 
fruits[1]="blueberry"
print(fruits)
# change multiple element by slicing
fruits[1:3]=["orange","graps"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'blueberry', 'cherry']
# ['apple', 'orange', 'graps']

# %% [markdown]
# list operations

# %%
# sorting
# list of numbers
numbers=[9,8,6,5,3,5,6,7,8]
print(numbers)

# sort the list
numbers.sort()
print(numbers)

# sort in descending order
numbers.sort(reverse=True)
print(numbers)

# sorting a list of strings
fruits = ["apple","banana","orange","stroberry","cherry"]
fruits.sort()
print(fruits)
# Out:
# [9, 8, 6, 5, 3, 5, 6, 7, 8]
# [3, 5, 5, 6, 6, 7, 8, 8, 9]
# [9, 8, 8, 7, 6, 6, 5, 5, 3]
# ['apple', 'banana', 'cherry', 'orange', 'stroberry']

# %% [markdown]
# Reversing

# %%
# list of numbers 
numbers=[1,2,3,4,5]
#reverse the list 
numbers.reverse()
print(numbers)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Joining List

# %%
# Two Lists of numbers
num1=[1,2,3,]
num2=[4,5,6]
# concatenate using +
combined = num1 + num2
print(combined)

#concatenate
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
#  list comprehensions

# %%
# creating a list of squares
squares = [x**2 for x in range(11)]
print(squares)

# filtering with list comphrension
even_squares = [x**2 for x in range(10)if x %2 ==0]
print(even_squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# [0, 4, 16, 36, 64]

# %% [markdown]
# List method

# %%
# count occurrences
#list of fruits
fruits=["apple","banana","blackberry","cherry"]

# countnthe occurences of an item 
index = fruits.index("banana")
print(index)

# count occurense
banana_count = fruits.count("banana")
print(banana_count)
# Out:
# 1
# 1

# %%
# list length
# list of fruits
fruits= ["apple","banana","cherry","orange"]

# get the length of list 
length = len(fruits)
print(length)
# Out:
# 4

# %% [markdown]
# iterating over lists

# %%
# list of fruits
fruits = ["apple","banana","cherry"]
# using a for loop

# %%
fruits = ["apple","banana","cherry"]
for index, fruits in enumerate(fruits):
     print (index,fruits)
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
#nesting
matrix = [[1,2,3],[4,5,6],[7,8,9]]

# asseccing
print(matrix[0])
print(matrix[0][1])
print(matrix[1][2])

#
for row in matrix: 
    for elem in row: 
        print(elem, end='')
# Out:
# [1, 2, 3]
# 2
# 6
# 123456789

# %% [markdown]
# Tuples():

# %%
#empty tuple
empty_tuples=()
print(empty_tuples)
#tuple of integer
numbers = (1,2,3,4,5)
print(numbers)
#tuple of srings
fruits =("apple","banana","cherry")
print(fruits)
# mixed data type
mixed_tuple =(1,"hello",3.15,True)
print(mixed_tuple)
# tuple function
another_tuple = tuple([1,2,3,4,5])
print(another_tuple)
# single element 
single_element_tuple = (42,)
print(single_element_tuple)
# Out:
# ()
# (1, 2, 3, 4, 5)
# ('apple', 'banana', 'cherry')
# (1, 'hello', 3.15, True)
# (1, 2, 3, 4, 5)
# (42,)

# %% [markdown]
# Accessing element in a tuple

# %%
fruits = ("apple","banana","cherry")

print(fruits[0])
print(fruits[1])
print(fruits[-1])

#slicing tuples

print(fruits[1:3])
print(fruits[:2])
print(fruits[1:])
# Out:
# apple
# banana
# cherry
# ('banana', 'cherry')
# ('apple', 'banana')
# ('banana', 'cherry')

# %%
# Tuple Method
# tuple of member
numbers = (1,2,2,3,4,2)

# Counting the occurence of element
count_of_twos = numbers.count(2)
print(count_of_twos)
# Out:
# 3

# %%
# index
fruits = ("apple","banana","cherry")

# finding index of an element
index_of_banana = fruits.index("banana")
print(index_of_banana)
# Out:
# 1

# %% [markdown]
# Basic tuple operation

# %%
# len()
fruits = ("apple","banana","cherry")

# Getting the lenght of tuple
length = len (fruits)
print(length)
# Out:
# 3

# %% [markdown]
# Contatenation

# %%
numbers1 = (1,2,3)
numbers2 = (4,5,6)

#Concatenation of tuple
combined = numbers1 + numbers2
print(combined)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# Repetition

# %%
single_element_tuple = ("hello ",)

# repeating
repeated_tuple = single_element_tuple * 3
print(repeated_tuple )

single_element_tuple = ("hello, ")

# repeating
repeated_tuple = single_element_tuple * 3
print(repeated_tuple )

single_element_tuple = ("hello,")

# repeating
repeated_tuple = single_element_tuple * 3
print(repeated_tuple )
# Out:
# ('hello ', 'hello ', 'hello ')
# hello, hello, hello,
# hello,hello,hello,

# %% [markdown]
# Membership

# %%
fruits = ("apple","banana","cherry")

#checking membership
print ("banana" in fruits)
print ("grape" in fruits)
# Out:
# True
# False

# %% [markdown]
# Iteration

# %%
fruits = ("apple","banana","cherry")

# iteration through tuple
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
# unpacking tuple
fruits = ("apple","banana","cherry")

# unpacking tuple
a,b,c = fruits
print(a)
print(b)
print(c)

# unpacking with more elements
numbers = (1,2,3,4,5)
first, *middle, last = numbers
print(first)
print(middle)
print(last)
# Out:
# apple
# banana
# cherry
# 1
# [2, 3, 4]
# 5

# %% [markdown]
# Advanced Tuple Usage

# %%
# Nested tuples
nested_tuple = ((1,2,3),("a","b","c"),(True,False))

#Accessing element in nested tuple
print(nested_tuple[0])
print(nested_tuple[0][1])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# 2
# c

# %% [markdown]
# Dictionary

# %%
tuple_dict = {
    (1,2): "a pair of numbers",
    ("x","y"): "a pair of letters"
}

# Accessing dictionary values using tuple key
print (tuple_dict[(1,2)])
print (tuple_dict[("x","y")])
# Out:
# a pair of numbers
# a pair of letters

# %%
# creating dictionary
person = {"name": "sakshi", "age":"21","city":"pune"}
print (person)
# Out:
# {'name': 'sakshi', 'age': '21', 'city': 'pune'}

# %%
#Creating dictionary using the dict() function
person2 = {"name": "rahul", "age":"49","city":"Yavatmal"}
print (person2)
# Out:
# {'name': 'rahul', 'age': '49', 'city': 'Yavatmal'}

# %% [markdown]
# Accessing values

# %%
# accessing using key
person = {"name": "sakshi", "age":"21","city":"pune"}
print (person["name"])
print (person["age"])

# using get() method to avoid keyError
print(person.get("city"))
print(person.get("country","not specified"))
print(person.get("address"))
# Out:
# sakshi
# 21
# pune
# not specified
# None

# %% [markdown]
# Modifying Dictionaries

# %%
person ["email"] = "sakshi@gmail.com"
print (person)

# updating existing key's value
person["age"]= 21
person["name"]="sakshi"
print(person)
# Out:
# {'name': 'sakshi', 'age': '21', 'city': 'pune', 'email': 'sakshi@gmail.com'}
# {'name': 'sakshi', 'age': 21, 'city': 'pune', 'email': 'sakshi@gmail.com'}

# %%
# remonving item with del
del person["email"]
print(person)

# remonving item with pop()
age = person.pop("age")
print(age)
print(person)
# Out:
# {'name': 'sakshi', 'age': 21, 'city': 'pune'}
# 21
# {'name': 'sakshi', 'city': 'pune'}

# %%
person.clear()
print(person)
# Out:
# {}

# %% [markdown]
# Dictionary Method

# %%
# keys()
person ={"name": "sakshi","age":21,"city":"pune"}
keys = person.keys()
print(keys)
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
# values()
values =person.values()
print (values)
# Out:
# dict_values(['sakshi', 21, 'pune'])

# %%
#items()
items = person.items()
print (items)
# Out:
# dict_items([('name', 'sakshi'), ('age', 21), ('city', 'pune')])

# %%
# update()
additional_info = {"email":"sakshi@gmail.com","phone":"1111111111"}
person.update(additional_info)
print(person)
# Out:
# {'name': 'sakshi', 'age': 21, 'email': 'sakshi@gmail.com', 'phone': '1111111111'}

# %%
# pop()
city = person.pop("city")
print(city)
print(person)
# Out:
# pune
# {'name': 'sakshi', 'age': 21}

# %%
#popitem()
last_item = person.popitem()
print(last_item)
print(person)
# Out:
# ('phone', '1111111111')
# {'name': 'sakshi', 'age': 21, 'email': 'sakshi@gmail.com'}

# %%
# copy
person_copy = person.copy()
print(person_copy)
# Out:
# {'name': 'sakshi', 'age': 21, 'email': 'sakshi@gmail.com'}

# %%
# fromkey
keys = ["name","age","city"]
default_dict= dict.fromkeys(keys, "unknown")
print(default_dict)
# Out:
# {'name': 'unknown', 'age': 'unknown', 'city': 'unknown'}

# %% [markdown]
# Iteratin over Dictionary

# %%
# Iteratin over keys()
for key in person.keys():
    print(key)

# Iteratin over values()
for value in person.values():
    print(value)

# Iteratin over key-values pairs
for key, value in person.items():
    print(f"{key}:{values}")
# Out:
# name
# age
# email
# sakshi
# 21
# sakshi@gmail.com
# name:dict_values(['sakshi', 21, 'sakshi@gmail.com'])
# age:dict_values(['sakshi', 21, 'sakshi@gmail.com'])
# email:dict_values(['sakshi', 21, 'sakshi@gmail.com'])

# %%
# counting the characater of each in srting
text="hello world"
char_count={}

for char in text :
    if char in char_count:
        char_count[char]+=1
    else:
        char_count[char]=1
    print(char_count)
# Out:
# {'h': 1}
# {'h': 1, 'e': 1}
# {'h': 1, 'e': 1, 'l': 1}
# {'h': 1, 'e': 1, 'l': 2}
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}
# {'h': 1, 'e': 1, 'l': 2, 'o': 1, ' ': 1}
# {'h': 1, 'e': 1, 'l': 2, 'o': 1, ' ': 1, 'w': 1}
# {'h': 1, 'e': 1, 'l': 2, 'o': 2, ' ': 1, 'w': 1}
# {'h': 1, 'e': 1, 'l': 2, 'o': 2, ' ': 1, 'w': 1, 'r': 1}
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1}
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}

# %% [markdown]
# Set

# %%
# creating set
fruits ={"apple","bananana","cherry"}
print (fruits)

# Creating a set using the set() function
numbers = set([1,2,3,4,5])
print (numbers)
# Out:
# {'bananana', 'cherry', 'apple'}
# {1, 2, 3, 4, 5}

# %%
# common set operation and methods
# adding items
fruits = {"apple","banana","guava","kivi","orange"}
fruits.add("papaya")
print(fruits)
# Out:
# {'papaya', 'orange', 'kivi', 'apple', 'banana', 'guava'}

# %%
# removig items
fruits = {"apple","banana","guava","kivi","orange"}
fruits.remove("apple")
print(fruits)
# Out:
# {'orange', 'kivi', 'banana', 'guava'}

# %%
# poping items
item = fruits.pop()
print(item)
print (fruits)
# Out:
# orange
# {'kivi', 'banana', 'guava'}

# %%
item = fruits.pop()
print(item)
print (fruits)
# Out:
# kivi
# {'banana', 'guava'}

# %%
item = fruits.pop()
print(item)
print (fruits)
# Out:
# banana
# {'guava'}

# %%
item = fruits.pop()
print(item)
print (fruits)
# Out:
# guava
# set()

# %%
# set clearing
fruits.clear()
print(fruits)
# Out:
# set()

# %%
fruits = {"apple","banana","guava","kivi","orange"}
print (fruits)
# Out:
# {'orange', 'kivi', 'apple', 'banana', 'guava'}

# %%
fruits.clear()
print(fruits)
# Out:
# set()

# %%
# set length
fruits = {"apple","banana","guava","kivi","orange"}
print(len(fruits))
# Out:
# 5

# %%
# membership testing 
print ("banana"in fruits)
print("grape"in fruits)
# Out:
# True
# False

# %% [markdown]
# Set Operation

# %%
# union
set1 = {1,2,3,4,5}
set2 = {3,4,5,6,7}
union_set = set1.union(set2)
print (union_set )
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
# Intersection
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {3}

# %%
# difference
difference_set = set1.difference(set2)
print(difference_set)
# Out:
# {1, 2}

# %%
# Symmetric difference
symmetric_difference_set =  set1.symmetric_difference(set2)
print(symmetric_difference_set)
# Out:
# {1, 2, 6, 7}

# %% [markdown]
# Set Operation

# %%
# subset
set1={1,2,3}
set2={3,4,5}
set3={1,2}
print(set3.issubset(set1))
print(set1 >= set3)

# superset
print(set3.issuperset(set1))
print(set1 >= set3)

# disjoin set
print(set3.isdisjoint(set1))
print(set1 >= set3)
# Out:
# True
# True
# False
# True
# False
# True

# %% [markdown]
# Difining a function

# %%
def greet(sakshi):
    """Function to greet a person . """
    return f"hello, {name}!"
    print(greet ("sakshi"))



# function arguments
def sum(a,b):
  calling with argument 
Sum(20,10)

# default parameter value
Def sum (a,)

# return values
-def square(x):
  return x*x
S=square (5)
# Out:
#   Cell In[64], line 10
#     calling with argument
#             ^
# SyntaxError: invalid syntax
